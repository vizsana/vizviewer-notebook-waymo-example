# %%
import sys
import os

# %%
import nbvizviewer.mqtt_client_server
api=nbvizviewer.mqtt_client_server.main()
# Out:
# [2020-06-10 01:03:15,570] :: [Thread-5] :: WARNING :: hbmqtt.client :: MQTT connection failed: OSError("Multiple exceptions: [Errno 111] Connect call failed ('127.0.0.1', 9091), [Errno 99] Cannot assign requested address")
# [2020-06-10 01:03:15,572] :: [Thread-5] :: WARNING :: hbmqtt.client :: Connection failed: ConnectException(OSError("Multiple exceptions: [Errno 111] Connect call failed ('127.0.0.1', 9091), [Errno 99] Cannot assign requested address"))

# %%
import tensorflow as tf
import math
import numpy as np
import itertools

sys.path.insert(0, '{}/waymo-od/'.format(os.getcwd()))

tf.enable_eager_execution()

from waymo_open_dataset.utils import range_image_utils
from waymo_open_dataset.utils import transform_utils
from waymo_open_dataset import dataset_pb2 as open_dataset
from waymo_open_dataset_local.utils import frame_utils

# %%
# %load_ext autoreload
# %autoreload 2
import vizviewer_waymo

# %%
vizviewer_waymo.vv_waymo_datarecords(api, '/waymo_data/', rate_hertz=5.0)
# Out:
# [2020-06-10 01:04:27,213] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,217] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,223] :: [Thread-4] :: ERROR :: websockets.server :: Error in connection handler
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/websockets/server.py", line 191, in handler
#     await self.ws_handler(self, path)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/broker.py", line 340, in ws_connected
#     yield from self.client_connected(listener_name, WebSocketsReader(websocket), WebSocketsWriter(websocket))
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/broker.py", line 463, in client_connected
#     yield from handler.mqtt_acknowledge_unsubscription(unsubscription['packet_id'])
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/broker_handler.py", line 107, in mqtt_acknowledge_unsubscription
#     yield from self._send_packet(unsuback)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,260] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,267] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,279] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,287] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,290] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 812, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,295] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,313] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,319] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,326] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,330] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,334] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,337] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,347] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,359] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,362] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,374] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,379] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,389] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,400] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,407] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,418] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,423] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,430] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,435] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,438] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,456] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,471] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,473] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,477] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,489] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,494] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,498] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,510] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,516] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,522] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,526] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,531] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,541] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,546] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,556] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,567] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,572] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,584] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,588] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,613] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,617] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,635] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,640] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,657] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,669] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:27,689] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# ...
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,377] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,412] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,419] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,524] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,527] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,545] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,548] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,565] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,570] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,620] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,624] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,663] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:31,669] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:42,174] :: [Thread-4] :: ERROR :: asyncio :: Task exception was never retrieved
# future: <Task finished coro=<ProtocolHandler.mqtt_publish() done, defined at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py:162> exception=ConnectionClosedError('code = 1005 (no status code [internal]), no reason')>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 187, in mqtt_publish
#     yield from self._handle_message_flow(message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 200, in _handle_message_flow
#     yield from self._handle_qos0_message_flow(app_message)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 221, in _handle_qos0_message_flow
#     yield from self._send_packet(packet)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 803, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:04:52,958] :: [ThreadPoolExecutor-0_0] :: ERROR :: asyncio :: Task was destroyed but it is pending!
# task: <Task pending coro=<BrokerProtocolHandler.get_next_pending_subscription() running at /opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/broker_handler.py:91> wait_for=<Future pending cb=[<TaskWakeupMethWrapper object at 0x7f09b41f2890>()]>>
# [2020-06-10 01:05:11,905] :: [Thread-4] :: WARNING :: hbmqtt.mqtt.protocol.handler :: Unhandled exception: code = 1005 (no status code [internal]), no reason
# [2020-06-10 01:05:11,914] :: [Thread-4] :: ERROR :: websockets.server :: Error in connection handler
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/websockets/server.py", line 191, in handler
#     await self.ws_handler(self, path)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/broker.py", line 340, in ws_connected
#     yield from self.client_connected(listener_name, WebSocketsReader(websocket), WebSocketsWriter(websocket))
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/broker.py", line 463, in client_connected
#     yield from handler.mqtt_acknowledge_unsubscription(unsubscription['packet_id'])
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/broker_handler.py", line 107, in mqtt_acknowledge_unsubscription
#     yield from self._send_packet(unsuback)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/protocol/handler.py", line 446, in _send_packet
#     yield from packet.to_stream(self.writer)
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/mqtt/packet.py", line 203, in to_stream
#     yield from writer.drain()
#   File "/opt/conda/lib/python3.7/site-packages/hbmqtt/adapters.py", line 120, in drain
#     yield from self._protocol.send(data)
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 555, in send
#     await self.ensure_open()
#   File "/opt/conda/lib/python3.7/site-packages/websockets/protocol.py", line 812, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: code = 1005 (no status code [internal]), no reason
